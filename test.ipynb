# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
GSPC = pd.read_csv('^GSPC.csv', parse_dates = True, index_col = 0)

# %%
sp_500 = GSPC['Adj Close']['2020']

# %%
plt.plot(sp_500)

# %%
HUI = pd.read_csv('GC=F.csv', parse_dates = True, index_col = 0)

# %%
HUI
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2020-01-06  1580.000000  1580.000000  1560.400024  1566.199951  1566.199951
# 2020-01-07  1558.300049  1576.300049  1558.300049  1571.800049  1571.800049
# 2020-01-08  1579.699951  1604.199951  1552.300049  1557.400024  1557.400024
# 2020-01-09  1555.699951  1555.699951  1543.300049  1551.699951  1551.699951
# 2020-01-10  1551.199951  1558.800049  1545.400024  1557.500000  1557.500000
# ...                 ...          ...          ...          ...          ...
# 2020-12-31  1897.000000  1901.300049  1892.699951  1893.099976  1893.099976
# 2021-01-03          NaN          NaN          NaN          NaN          NaN
# 2021-01-04  1912.199951  1945.099976  1912.199951  1944.699951  1944.699951
# 2021-01-05  1941.699951  1952.699951  1941.300049  1952.699951  1952.699951
# 2021-01-06  1952.800049  1962.500000  1902.599976  1908.199951  1908.199951
#
#               Volume
# Date
# 2020-01-06     416.0
# 2020-01-07      47.0
# 2020-01-08     236.0
# 2020-01-09      54.0
# 2020-01-10      16.0
# ...              ...
# 2020-12-31     127.0
# 2021-01-03       NaN
# 2021-01-04     154.0
# 2021-01-05     154.0
# 2021-01-06  296817.0
#
# [306 rows x 6 columns]

# %%
IXIC = pd.read_csv('^IXIC.csv', parse_dates = True, index_col = 0)

# %%
gold = HUI['Adj Close']['2020']

# %%
plt.plot(gold)

# %%
nasdac= IXIC['Adj Close']['2020']

# %%
plt.plot(nasdac)

# %%
plt.figure(figsize=(16,9))
plt.fill_between(nasdac.index,nasdac.max(), color = '#fad586')
plt.fill_between(nasdac.index, nasdac, color = '#d6efc7')
plt.fill_between(sp_500.index, sp_500, color = '#96bb7c')
plt.fill_between(gold.index, gold, color = '#184d47')
plt.savefig('hoe.png')

# %%
def fscaled(x):
    return (x - x.min()) / (x.max() - x.min())

# %%
gold_fs = fscaled(gold)
sp_fs = fscaled(sp_500)

# %%
gold
# Out:
# Date
# 2020-01-06    1566.199951
# 2020-01-07    1571.800049
# 2020-01-08    1557.400024
# 2020-01-09    1551.699951
# 2020-01-10    1557.500000
#                  ...
# 2020-12-27            NaN
# 2020-12-28    1877.199951
# 2020-12-29    1879.699951
# 2020-12-30    1891.000000
# 2020-12-31    1893.099976
# Name: Adj Close, Length: 302, dtype: float64

# %%
sp_500
# Out:
# Date
# 2020-01-06    3246.280029
# 2020-01-07    3237.179932
# 2020-01-08    3253.050049
# 2020-01-09    3274.699951
# 2020-01-10    3265.350098
#                  ...
# 2020-12-24    3703.060059
# 2020-12-28    3735.360107
# 2020-12-29    3727.040039
# 2020-12-30    3732.040039
# 2020-12-31    3756.070068
# Name: Adj Close, Length: 251, dtype: float64

# %%
IXIC
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-01-06   8943.500000   9072.410156   8943.500000   9071.469727
# 2020-01-07   9076.639648   9091.929688   9042.549805   9068.580078
# 2020-01-08   9068.030273   9168.889648   9059.379883   9129.240234
# 2020-01-09   9202.269531   9215.950195   9158.500000   9203.429688
# 2020-01-10   9232.950195   9235.200195   9164.660156   9178.860352
# ...                  ...           ...           ...           ...
# 2020-12-30  12906.509766  12924.929688  12857.759766  12870.000000
# 2020-12-31  12877.089844  12902.070313  12821.230469  12888.280273
# 2021-01-04  12958.519531  12958.719727  12543.240234  12698.450195
# 2021-01-05  12665.650391  12828.269531  12665.650391  12818.959961
# 2021-01-06  12666.200195  12894.829102  12649.989258  12885.431641
#
#                Adj Close      Volume
# Date
# 2020-01-06   9071.469727  2788120000
# 2020-01-07   9068.580078  2352850000
# 2020-01-08   9129.240234  2464090000
# 2020-01-09   9203.429688  2534700000
# 2020-01-10   9178.860352  2378990000
# ...                  ...         ...
# 2020-12-30  12870.000000  5292210000
# 2020-12-31  12888.280273  4771390000
# 2021-01-04  12698.450195  6546740000
# 2021-01-05  12818.959961  6904420000
# 2021-01-06  12885.431641  3616462233
#
# [254 rows x 6 columns]

# %%
TORP = pd.read_csv('TORP.csv', index_col = 0, parse_dates = True)

# %%
TORP = TORP['2010':'2021']

# %%
rets = TORP['Adj Close'].pct_change()

# %%
pip install pandas-datareader --upgrade
# Out:
# Collecting pandas-datareader
#   Using cached pandas_datareader-0.9.0-py3-none-any.whl (107 kB)
# Collecting requests>=2.19.0
#   Using cached requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Requirement already satisfied, skipping upgrade: pandas>=0.23 in c:\users\unnik\appdata\roaming\python\python37\site-packages (from pandas-datareader) (1.2.0)
# Requirement already satisfied, skipping upgrade: lxml in c:\users\unnik\anaconda3\lib\site-packages (from pandas-datareader) (4.6.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\unnik\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2.8)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\unnik\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (2020.12.5)
# Requirement already satisfied, skipping upgrade: chardet<5,>=3.0.2 in c:\users\unnik\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in c:\users\unnik\anaconda3\lib\site-packages (from requests>=2.19.0->pandas-datareader) (1.25.8)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.5 in c:\users\unnik\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.19.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in c:\users\unnik\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in c:\users\unnik\anaconda3\lib\site-packages (from pandas>=0.23->pandas-datareader) (2019.3)
# Requirement already satisfied, skipping upgrade: six>=1.5 in c:\users\unnik\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.14.0)
# Installing collected packages: requests, pandas-datareader
#   Attempting uninstall: requests
#     Found existing installation: requests 2.10.0
#     Uninstalling requests-2.10.0:
#       Successfully uninstalled requests-2.10.0
#   Attempting uninstall: pandas-datareader
#     Found existing installation: pandas-datareader 0.8.1
#     Uninstalling pandas-datareader-0.8.1:
#       Successfully uninstalled pandas-datareader-0.8.1
# Successfully installed pandas-datareader-0.9.0 requests-2.25.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: cg-acc 1.2.2 has requirement requests==2.10.0, but you'll have requests 2.25.1 which is incompatible.

# %%
import pandas_datareader.data as web
import pandas as pd 
import numpy as np 
from datetime import datetime
import matplotlib.pyplot as plt

# %%
S = pd.DataFrame()
Tickers = ['SBIN.NS', 'TCS.NS', 'INFY.NS', 'TORNTPHARM.NS']

# %%
start = datetime(2016, 9, 1)
end = datetime(2018, 9, 1)
start1 = '2016-09-01'
end1 = '2018-09-01'

# %%
for t in Tickers:
  S[t] = web.DataReader(t, 'yahoo', start, end)['Close']

# %%
S.head()
# Out:
#                SBIN.NS       TCS.NS     INFY.NS  TORNTPHARM.NS
# Date
# 2016-09-01  252.000000  1253.750000  518.775024    1599.300049
# 2016-09-02  254.600006  1257.400024  515.924988    1610.449951
# 2016-09-06  260.100006  1242.030029  522.500000    1631.300049
# 2016-09-07  266.799988  1220.280029  527.174988    1618.199951
# 2016-09-08  268.350006  1161.050049  518.825012    1682.050049

# %%
mean = S.max()

# %%
mean
# Out:
# SBIN.NS           337.500000
# TCS.NS           2082.399902
# INFY.NS           720.549988
# TORNTPHARM.NS    1812.800049
# dtype: float64

# %%
val = []

# %%
for i in range(len(mean)):
    val.append((mean.values[i], mean.index[i]))

# %%
val.sort()
val = val[::-1]

# %%
# Out:
# [(1101.0699462890625, 'HDFCBANK.NS'),
#  (781.2000122070312, 'LICHSGFIN.NS'),
#  (651.9400024414062, 'CANFINHOME.NS'),
#  (85.1500015258789, 'IDBI.NS')]

# %%
import seaborn as sns
num_shades = 8
sns.palplot(sns.cubehelix_palette(num_shades))

# %%
str(np.random.random())
# Out:
# '0.4588024960785041'

# %%
str(np.random.random())[1:3]
# Out:
# '.5'

# %%
color_list = sns.cubehelix_palette(num_shades, rot=-float(str(np.random.random())[1:3]))

# %%
sns.palplot(

# %%
pal = sns.color_palette(sns.cubehelix_palette(num_shades, rot=-float(str(np.random.random())[1:3])))
col = pal.as_hex()

# %%
plt.figure(figsize=(16,9))
plt.fill_between(S[val[0][1]].index,S[val[0][1]].max(), color = str(col[0]))
for temp in range(len(val)):
    i = val[temp][1]
    plt.fill_between(S[i].index,S[i], color = str(col[temp + 1]))
plt.savefig(i + '.png')

# %%
type(col[0])
# Out:
# str
